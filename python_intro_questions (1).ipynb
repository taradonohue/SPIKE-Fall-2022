# %%
def run_question_1():
    import ipywidgets as widgets
    from ipywidgets import HBox, Label, Layout

    question_1 = widgets.Dropdown(
        options=['Yes', 'No','Choose your answer',],
        value='Choose your answer',
        description='1.',
    )

    def answer_1(change):
        if change['new'] == 'Yes':
            print("Correct! You can use single or double quotations in print statements.")
          
        elif change['new'] == 'No':
            print("Try again!")
      
    question_1.observe(answer_1)

    print("Are the statements below correct examples of print statements?")
    print()
    print("1. print('Hello!')")
    display(question_1)

    question_2 = widgets.Dropdown(
        options=['Yes', 'No','Choose your answer',],
        value='Choose your answer',
        description='2.',
    )

    def answer_2(change):
        if change['new'] == 'Yes':
            print("Correct! You can use single or double quotations in print statements.")
          
        elif change['new'] == 'No':
            print("Try again!")
      
    question_2.observe(answer_2)

    print()
    print('2. print("Hello!")')
    display(question_2)

    question_3 = widgets.Dropdown(
        options=['Yes', 'No','Choose your answer',],
        value='Choose your answer',
        description='3.',
    )

    def answer_3(change):
        if change['new'] == 'Yes':
            print("Try again!")
          
        elif change['new'] == 'No':
            print("Correct! You have to use quotations in print statements when printing messages like this one!")
      
        question_3.observe(answer_3)

    print()
    print('3. print(Hello!)')
    display(question_3)
    
def run_question_1():
    import ipywidgets as widgets
    from ipywidgets import Button, Layout, jslink, IntText, IntSlider
    from ipywidgets import AppLayout, Button, Layout


    q1_button1 = widgets.Button(description="Yes")
    q1_button2 = widgets.Button(description="No")

    q2_button1 = widgets.Button(description="Yes")
    q2_button2 = widgets.Button(description="No")

    q3_button1 = widgets.Button(description="Yes")
    q3_button2 = widgets.Button(description="No")

    print("Are the statements below correct examples of print statements?")
    print("")
    print("print('Hello!')")
    display(widgets.HBox((q1_button1, q1_button2)))
    print("")
    print('print("Hello!")')
    display(widgets.HBox((q2_button1, q2_button2)))
    print("")
    print('print(Hello!)')
    display(widgets.HBox((q3_button1, q3_button2)))
    print("")

    def q1_answer_wrong(b):
        print("Try again!")

    q1_button2.on_click(q1_answer_wrong)

    def q1_answer_right(b):
            print("Correct! You can use single or double quotations in print statements.")
            
    q1_button1.on_click(q1_answer_right)

    def q2_answer_wrong(b):
        print("Try again!")

    q2_button2.on_click(q1_answer_wrong)

    def q2_answer_right(b):
        print("Correct! You can use single or double quotations in print statements.")

    q2_button1.on_click(q1_answer_right)

    def q3_answer_wrong(b):
        print("Try again!")

    q3_button1.on_click(q3_answer_wrong)

    def q3_answer_right(b):
        print("Correct! You have to use quotations in print statements when printing messages like this one!")

    q3_button2.on_click(q3_answer_right)

# %%
#run_question_1()

# %%
def run_question_2():
    import ipywidgets as widgets
    from ipywidgets import Button, Layout, jslink, IntText, IntSlider
    from ipywidgets import AppLayout, Button, Layout

    int_button = widgets.Button(description="Integer")
    float_button = widgets.Button(description="Floating-point")
    str_button = widgets.Button(description="String")

    print("What type is the following value?")
    print('"2.0"')
    display(widgets.HBox((int_button,float_button,str_button)))

    def answer_wrong(b):
        print("Try again!")

    int_button.on_click(answer_wrong)
    float_button.on_click(answer_wrong)

    def answer_right(b):
        print("Correct! Putting quotes around the number makes it a string.")
        
    str_button.on_click(answer_right)

# %%
#run_question_2()

# %%
def run_question_3():
    import ipywidgets as widgets
    from ipywidgets import Button, Layout, jslink, IntText, IntSlider
    from ipywidgets import AppLayout, Button, Layout


    q1_button1 = widgets.Button(description="class_1")
    q1_button2 = widgets.Button(description="1st_class")

    q2_button1 = widgets.Button(description="my school")
    q2_button2 = widgets.Button(description="my_school")

    q3_button1 = widgets.Button(description="dining!table")
    q3_button2 = widgets.Button(description="DiningTable")

    display(widgets.HBox((q1_button1, q1_button2)))
    print("")
    display(widgets.HBox((q2_button1, q2_button2)))
    print("")
    display(widgets.HBox((q3_button1, q3_button2)))
    print("")

    def q1_answer_wrong(b):
        print("Try again!")

    q1_button1.on_click(q1_answer_wrong)

    def q1_answer_right(b):
        print("Correct. In Python, variable names can use numbers, but they can't be at the beginning of the name.")

    q1_button2.on_click(q1_answer_right)

    def q2_answer_wrong(b):
        print("Try again!")

    q2_button2.on_click(q1_answer_wrong)

    def q2_answer_right(b):
        print("Correct. You can't use spaces in variable names, but you can use underscores.")

    q2_button1.on_click(q1_answer_right)

    def q3_answer_wrong(b):
        print("Try again!")

    q3_button2.on_click(q3_answer_wrong)

    def q3_answer_right(b):
        print("Correct. You can't use special characters like an exclamation point, but you can use capital letters.")

    q3_button1.on_click(q3_answer_right)

# %%
def check_volume():
    volume_actual = 24

    if volume_calculated == volume_actual:
        print("Great job! The volume is correct.")
    else:
        print("Try again! The volumes don't match. Check to see if you set your variables correctly!")

# %%
def reveal_answer1():
    print('print("Hi, how are you?")')

# %%
def reveal_answer2():
    print('length = 3')
    print('width = 4')
    print('height = 2')
    print('')
    print("volume_calculated = length*width*height")

# %%
def reveal_answer3():
    print('def repeat_song():')
    print('     '  + 'print_song()')
    print('     '  + 'print_song()')
    print('repeat_song()')

# %%
def reveal_answer4():
    print('temperature = 30')
    print('precipitation_likely = False')
    print('')
    print('if temperature >= 65 and precipitation_likely == True:')
    print('    ' + 'print("It might rain. You should bring an umbrella!")')
    print('elif temperature >= 65 and precipitation_likely == False:')
    print('    ' + 'print("It is nice out, you are all set!")')
    print('elif temperature >= 32 and temperature < 65 and precipitation_likely == False:')
    print('    ' + 'print("It is pretty cold, you might want a jacket!")')
    print('elif temperature >= 32 and temperature < 65 and precipitation_likely == True:')
    print('    ' + 'print("It is pretty cold and it might rain. Bring a warm rain jacket!")')
    print('elif temperature < 32 and precipitation_likely == True:')
    print('    ' + 'print("It looks like it might snow. Bring a warm jacket and snow boots!")')
    print('elif temperature < 32 and precipitation_likely == False:')
    print('    ' + 'print("It looks very cold. Bring a warm jacket!")')
